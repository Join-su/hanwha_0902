# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = PromptTemplate.from_template("{topic} 에 대해 쉽게 설명해주세요.")
model = ChatOpenAI()

input = {"topic":"인공지능 모델의 학습 원리"}

# %%
print(prompt)
print(input)
# Out:
# input_variables=['topic'] input_types={} partial_variables={} template='{topic} 에 대해 쉽게 설명해주세요.'
# {'topic': '인공지능 모델의 학습 원리'}

# %%
output_parser = StrOutputParser()
output_parser
# Out:
# StrOutputParser()

# %%
chain = prompt | model | output_parser

# %%
# invoke : 문자열로 된 답변 얻음.
input = {"topic": "인공지능 모델의 학습 원리"}
chain.invoke(input)
# Out:
# '인공지능 모델의 학습 원리는 데이터를 입력으로 받아들이고, 이 데이터를 분석하여 패턴을 학습하는 것입니다. 이때 모델은 입력 데이터를 기반으로 일련의 계산을 수행하여 원하는 결과를 도출합니다.\n\n학습은 주어진 데이터와 모델의 파라미터를 조정해가면서 오차를 최소화하도록 수행됩니다. 이는 모델이 데이터를 계속해서 반복해서 학습하면서 새로운 데이터에 대해 더 잘 예측할 수 있도록 하는 과정입니다.\n\n학습 원리는 주어진 데이터를 통해 모델이 패턴을 학습하고, 이를 바탕으로 문제를 해결하거나 새로운 데이터에 대해 예측하는 데 사용됩니다.'

# %%
template = """
당신은 영어를 가르치는 10년차 영어 선생님입니다. 주어진 상황에 맞는 영어 회화를 작성해 주세요.
양식은 [FORMAT]을 참고하여 작성해 주세요.

#상황:
{question}

#FORMAT:
- 영어 회화:
- 한글 해석:
"""

# %%
prompt = PromptTemplate.from_template(template)

# ChatOpenAI 챗모델을 초기화.
model = ChatOpenAI(model_name="gpt-4o-mini")

# 문자열 출력 파서를 초기화.
output_parser = StrOutputParser()

# %%
# 체인을 구성합니다.
chain = prompt | model | output_parser

# %%
chain.invoke({"question": "저는 식당에 가서 음식을 주문하고 싶어요"})
# Out:
# '- 영어 회화:\nA: Hello! Welcome to our restaurant. How many people are in your party?\nB: Hi! There are two of us.\nA: Great! Please follow me to your table. Here’s the menu. Can I get you anything to drink?\nB: Yes, I’ll have a glass of water, please. And my friend would like a soda.\nA: Sure! I’ll be right back with your drinks. Are you ready to order your food?\nB: Yes, I would like the grilled chicken salad, and my friend will have the spaghetti.\nA: Excellent choices! I’ll put that in for you. Would you like anything else?\nB: No, that’s all for now. Thank you!\nA: You’re welcome! Enjoy your meal!\n\n- 한글 해석:\nA: 안녕하세요! 저희 식당에 오신 것을 환영합니다. 몇 분이신가요?\nB: 안녕하세요! 저희는 두 명이에요.\nA: 좋습니다! 저를 따라오세요. 여기가 당신의 테이블입니다. 메뉴를 드릴게요. 음료수는 어떤 걸 드릴까요?\nB: 네, 물 한 잔 주세요. 그리고 제 친구는 탄산음료를 원해요.\nA: 알겠습니다! 음료를 금방 가져다 드릴게요. 음식은 지금 주문하시겠어요?\nB: 네, 저는 그릴드 치킨 샐러드를 원하고, 제 친구는 스파게티를 주문할게요.\nA: 훌륭한 선택입니다! 지금 주문 넣을게요. 다른 추가할 것이 있으신가요?\nB: 아니요, 지금은 그게 다예요. 감사합니다!\nA: 천만에요! 맛있게 드세요!'

# %%
from langchain_teddynote.messages import stream_response  # 스트리밍 출력
answer = chain.stream({"question": "미국에서 피자 주문"})
# 스트리밍 출력
stream_response(answer)

# 랭스미스 Tracing에서 도 확인해보자 ㅎ
# Out:
# - 영어 회화:
# A: Hi, I’d like to order a pizza, please.
# B: Sure! What size do you want?
# A: I’ll have a large, please. Can I get half pepperoni and half vegetarian?
# B: Of course! Would you like any extra toppings?
# A: Yes, please add mushrooms and olives to the vegetarian side.
# B: Great choice! Would you like any drinks or sides?
# A: No, just the pizza for now. How much will that be?
# B: That'll be $22.50. Would you like to pick it up or have it delivered?
# A: I’ll pick it up. What time will it be ready?
# B: It should be ready in about 20 minutes.
# A: Perfect, thank you!
#
# - 한글 해석:
# A: 안녕하세요, 피자를 주문하고 싶어요.
# B: 물론이죠! 어떤 사이즈로 하시겠어요?
# A: 대자로 주세요. 반은 페퍼로니, 반은 채식으로 해주세요.
# B: 알겠습니다! 추가 토핑을 원하시나요?
# A: 네, 채식 쪽에 버섯과 올리브 추가해 주세요.
# B: 좋은 선택이에요! 음료수나 사이드 메뉴는 필요하신가요?
# A: 아니요, 지금은 피자만요. 가격은 얼마인가요?
# B: 총 $22.50입니다. 포장해 가시나요, 아니면 배달하길 원하시나요?
# A: 포장해 갈게요. 언제 준비되나요?
# B: 약 20분 후에 준비될 거예요.
# A: 완벽해요, 감사합니다!

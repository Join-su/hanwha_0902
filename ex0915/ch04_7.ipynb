# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
model = ChatOpenAI()

prompt = PromptTemplate.from_template("{topic} 에 대하여 3문장으로 설명해줘.")
# 프롬프트와 모델을 연결하여 대화 체인을 생성합니다.
chain = prompt | model | StrOutputParser()

# %%
chain
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='{topic} 에 대하여 3문장으로 설명해줘.')
# | ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.2', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x00000241B9298230>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000241BB1AEEA0>, root_client=<openai.OpenAI object at 0x00000241BA9E2000>, root_async_client=<openai.AsyncOpenAI object at 0x00000241BB067920>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)
# | StrOutputParser()

# %%
chain.batch([{"topic":"ChatGPT"}, {"topic":"Instagram"}])
# Out:
# ['ChatGPT는 인공지능 채팅 모델로, 다양한 주제에 대해 대화를 나눌 수 있습니다. 사용자의 질문에 답변하거나 대화를 이끌어 갈 수 있어 정보나 엔터테인먼트 등 다양한 용도로 활용됩니다. 텍스트 기반으로 작동하여 사용자들과 자연스럽게 상호작용할 수 있습니다.',
#  'Instagram은 사진과 동영상을 공유하고 다른 사람의 게시물을 열람하는 소셜 미디어 플랫폼이다. 유명인들이나 브랜드들도 활발하게 활동하여 다양한 콘텐츠를 제공한다. 좋아요와 댓글을 통해 소통하며 사용자들끼리 소셜 네트워킹을 할 수 있다.']

# %%
answer = chain.batch([{"topic":"ChatGPT"}, {"topic":"Instargram"}])
print(answer)
print(answer[0])
# Out:
# ['ChatGPT는 OpenAI에서 개발된 대화형 인공 지능 모델로, 자연어로 대화를 주고받을 수 있습니다. ChatGPT는 사용자 질문에 적절한 답변을 생성하며, 다양한 주제에 대해 대화를 이어나갈 수 있습니다. ChatGPT는 광범위한 지식과 언어 모델을 바탕으로 작동하여, 사용자와 자연스럽게 상호작용하는 챗봇 역할을 수행합니다.', '인스타그램은 사진과 동영상을 공유할 수 있는 소셜 미디어 플랫폼이며, SNS에서 가장 인기 있는 앱 중 하나이다. 다양한 필터와 효과를 이용하여 사진을 보다 멋지게 편집할 수 있고, 팔로워들과 소통할 수 있는 기회를 제공한다. 또한 해시태그를 통해 관심사나 주제에 맞는 게시물을 찾을 수 있어 사용자들에게 다양한 콘텐츠를 제공한다.']
# ChatGPT는 OpenAI에서 개발된 대화형 인공 지능 모델로, 자연어로 대화를 주고받을 수 있습니다. ChatGPT는 사용자 질문에 적절한 답변을 생성하며, 다양한 주제에 대해 대화를 이어나갈 수 있습니다. ChatGPT는 광범위한 지식과 언어 모델을 바탕으로 작동하여, 사용자와 자연스럽게 상호작용하는 챗봇 역할을 수행합니다.

# %%
# "max_concurrency": 3 동시에 세개씩 처리함.
chain.batch(
    [
        {"topic": "ChatGPT"},
        {"topic": "Instagram"},
        {"topic": "멀티모달"},
        {"topic": "프로그래밍"},
        {"topic": "머신러닝"},
    ],
    config={"max_concurrency": 3},
)
# Out:
# ['ChatGPT는 세계에서 가장 강력한 인공지능 대화 시스템 중 하나로, 사용자들과 자연스럽고 효과적인 대화를 이어나갑니다. 주제에 관계없는 다양한 주제에 대해 대화할 수 있으며, 지식을 나누고 질문에 답변합니다. 자연어 처리 기술을 사용하여 사용자들과 소통함으로써 새로운 경험과 기회를 제공합니다.',
#  'Instagram은 사진과 영상을 공유하는 소셜 미디어 플랫폼으로, 전 세계적으로 인기를 누리고 있다. 사용자들은 다양한 필터와 효과로 사진을 가공하고, 팔로워들과 소통하며 일상을 공유한다. 또한 인플루언서들이 활발하게 활동하고 상업적인 활용이 많이 일어나는 대중적인 SNS이다.',
#  '멀티모달은 여러 가지 형태의 다양한 미디어를 혼합하여 정보를 전달하는 방식이다. 이는 텍스트, 이미지, 음성, 비디오 등 다양한 형태의 미디어를 결합하여 더 풍부한 경험을 제공한다. 멀티모달은 사용자들에게 다양한 감각을 자극하여 더 쉽고 효과적으로 정보를 전달할 수 있는 장점이 있다.',
#  '프로그래밍은 컴퓨터에게 작업을 수행하도록 지시하는 일련의 명령어를 작성하는 과정입니다. 이러한 명령어는 특정 프로그래밍 언어를 사용하여 작성되며, 정확하고 명확해야 합니다. 프로그래밍을 통해 우리는 다양한 소프트웨어 및 애플리케이션을 개발하고 문제를 해결할 수 있습니다.',
#  '머신러닝은 컴퓨터 시스템이 데이터를 분석하고 학습함으로써 패턴을 발견하고 예측하는 인공지능 기술이다. 이를 통해 인간의 개입 없이 스스로 문제를 해결하고 의사결정을 내릴 수 있게 된다. 머신러닝은 산업, 의료, 금융 등 다양한 분야에서 활용되며 혁신적인 변화를 이끌어내고 있다.']

# %%
async for token in chain.astream({"topic": "YouTube"}):
    # 메시지 내용을 출력합니다. 줄바꿈 없이 바로 출력하고 버퍼를 비웁니다.
    print(token, end="", flush=True)
# Out:
# YouTube 는 구글이 운영하는 동영상 공유 플랫폼으로, 온라인상에서 다양한 동영상 콘텐츠를 시청하고 업로드할 수 있습니다. 누구나 무료로 가입하고 동영상을 업로드하거나 시청할 수 있으며, 다양한 채널과 카테고리에서 원하는 콘텐츠를 찾아 볼 수 있습니다. 유명 인터넷 스타들이나 콘텐츠 크리에이터들이 활발하게 활동하는 플랫폼으로, 국내외에서 인기를 끌고 있는 온라인 비디오 플랫폼 중 하나입니다.

# %%
# 비동기 체인 객체의 'ainvoke' 메서드를 호출하여 'NVDA' 토픽을 처리합니다.
my_process = chain.ainvoke({"topic": "NVDA"})

# %%
# 비동기로 처리되는 프로세스가 완료될 때까지 기다립니다.
await my_process
# Out:
# 'NVDA는 미국의 기술 기업인 NVIDIA Corporation을 나타내는 주식 코드이다. 그들은 GPU(그래픽 처리 장치)와 시스템 온 칩(SoC)를 개발하고 제조하는 세계적인 기업으로 알려져 있다. NVDA주식은 기술 산업에 대한 투자자들 사이에서 많은 인기를 누리고 있다.'

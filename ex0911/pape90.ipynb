# %%
from openai import OpenAI
import os

# %%
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))
# client = OpenAI()

response=client.responses.create(
    model="gpt-5-mini",
    input="start"
)

print(response.output_text)
# Out:
# Hi — ready when you are. What would you like to do?
#
# Here are some things I can help with:
# - Answer questions or explain concepts
# - Draft or edit email, essays, resumes
# - Generate or review code; debug issues
# - Plan projects, trips, workouts, or meals
# - Create summaries or expand notes
# - Analyze images you upload
#
# Or just tell me your task in one sentence and I’ll get started.

# %%
print(response)
# Out:
# Response(id='resp_09a1efeb4bf0ac92006aa37317f29887d0a00bb23dab6a1c4b', created_at=1789096728.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-mini-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_09a1efeb4bf0ac92006aa373187d7c87d0acca96160076c576', summary=[], type='reasoning', content=[], encrypted_content='gAAAAABqo3Mb6hL8Ye_oZ7pGNugQFPw_FDtEDUIfq6ax6jcsVzDLEuD7ME0eagrm0Ds-pjyZwg3lWBZiQG57OtW9Uubqm01NfGbCGL8aROfxCZW_bxTR3w5bc9-ZkAGef6bMVzT2d0aXSGLmXf1jdS_E7v-SaEnGXD3O_ogGFk2mFjZL6GOoeBNeEStMCTKI0HeVB7Xp6WlcPhZ7QDFIt3p5kTY82cerrHjcp7pSPTbZJJLT-lNUSG8DD0XPKkzHZhhrFdfLXZj3TyBl8-edwvW8Z3UKm03_SYJoz-GBTYpXfyuCqimxKZ9-kr-pjOZvjo4Usd3llja5kxE4HRXKFiZJc_3gFYvkL0gYW2goOil8bFrG12151bhpYsgmEesR6hZ9as4HmMQ47Zx_vFW7rsN4x7_srrmRXStMZzkZa8GEDo8yJaMmHnXLWBQmA41knHdEGp6MNZi2MBga7q8_POOXpcdX_VNcexzw0abASiUcQ31XOzLWZrbdt9csQRHtUviQzW-S5HaVYMBOJNFYsPrAASdQoMViYzlet0fbUvou0DexPRQyRG6U3QDLnb8bTaXVDPF-AyArnVDpIPgN418AQGHBRE4oboDL34YaVePVHzC5FZ6h5gh9oBA02cyIQ9D4IeWQThyUu7Oze9HUaPzyDwYtnOstIKNsiX5UFV323nzyF99-2MC4Wsxq3nI98z90m1BS4uZXlABsxW8sRAexHE3hsRs1QB-9_oK1LMJUidgngYZSJDvpWw91ibbseh5tlCFmAZyojk9J0BB91e5Ki60XByFJhRVU4FgewCUvE-LMLy4D8-VpzDIqMJUIvBXhD9pUzbNRkY8PAn8g_l4UYpEX6Os2R2PtUaQN86abxW4EyFKKFJSmlMIK9aZje62JvEttLNVrxk7f8xBBQuQOtwB_Yg1Zi5plHTpoNlM7ghIGC17A8MYGHxrHXoKXaVVCrgsNk_6I43eVAZfQLXZIizJH4DmBIVe3gJXzaCeMa-LAM4v9q1F65BWl1HTsgQfsVtJHRb6FvKuHIJI7cQtU-557eAs-MijgRW2dho4kr7iPfDT1pmtzNE8XZGzmaqETJambLPTIovJg3Z27cHvEuay9RPKswCpw4HzwEmQEDl6FswVzjembIah0V_zvy5X57pUviFfaDPJiZ5rs2XmVa_emsfca4tEuwNKsCEUPYdRkShL_yGN7qQLH9SkofQ_5LLl4w4xPYY6qFU9oftzve_KDvj_Jbj3BfJFq_ZRwTaW9xZ1T-frPQdEtUz-s8LVXOnxhYcCOrdJOERWzIHG8OOMY6maCL8myf93ZVfN9FGjUdtuHjBmSbd8ueyZHrrC6yQBnVl8KHaU3-MzqGmPdTEKO9EMNcaE30oEhnbeL984eWk0oYYOZYylsWBIe8GZj6PpQu5pwwq34S17aXudyXqmzAs4CmOoyo-pw2V_GpS40tjH4nFBEVBfb7vupNxgZwaTHF5isoXyC7jrIVS99i6pWoSMl8400MtILyJoPnWZirSoBjqKoGVyaS-morIV9GMAjo5nqCdwA12TCGtVFZVBVou6qBA4sKQmujwK3wNYiQSCCRrtb2lp6ofrs17oFbYUJEuz-ylExcLl1MMoZ5jgT-aPRrM3cJBLudcKLPk4tHRHRXGGrki_S8GuidIwseErbDq2ZAKMYM6j42LjpNigTGb340sYsw1FVtsKzzeh1CPsape4r52nfvFxC-nLsGtzbxvGpfFJHu7L-FF6FLFQ5kSpZYt25RebkWH9Ef6uJC6w_7A8TIB0hv1-uFqj8BcRYnn3lwVu3vlXyfheyfTe6zTMTT80rrDbGB9umaIR-zm7ye2dmQ-5GphHw_lWJylijx5uIp5-wtEafVd0YyVanRP4Gq1MlVEKDIIrgxYbTfezjCB92i21t6NJPlgx4Ke0GyVkRFa7yPf1Bd4t8X2uyLxoyiX3xwH_O5L-jZJIzaO25hrur17KY_OdhwtsUozkim9KkexsPj9mW9i-1xa55uM5ReDVVqekwn9WI-ULNRYAkN3YEKHmgW0X4sfwiCmhOtNHOff6xJIXrZzK-TiD2FSYKAOLR97WAPRE53abPba7nD1DWkrlExHsP7_eSmTKhwIMo', status=None), ResponseOutputMessage(id='msg_09a1efeb4bf0ac92006aa3731a8d5887d0b5b06a67fbda2ad0', content=[ResponseOutputText(annotations=[], text='Hi — ready when you are. What would you like to do?\n\nHere are some things I can help with:\n- Answer questions or explain concepts\n- Draft or edit email, essays, resumes\n- Generate or review code; debug issues\n- Plan projects, trips, workouts, or meals\n- Create summaries or expand notes\n- Analyze images you upload\n\nOr just tell me your task in one sentence and I’ll get started.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None)], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, completed_at=1789096731.0, conversation=None, max_output_tokens=None, max_tool_calls=None, moderation=None, previous_response_id=None, prompt=None, prompt_cache_diagnostics=None, prompt_cache_key=None, prompt_cache_options=None, prompt_cache_retention='in_memory', reasoning=Reasoning(context='current_turn', effort='medium', generate_summary=None, mode='standard', summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=7, input_tokens_details=InputTokensDetails(cache_write_tokens=0, cached_tokens=0), output_tokens=244, output_tokens_details=OutputTokensDetails(reasoning_tok ...

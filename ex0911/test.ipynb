# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(
    temperature=0.1,
    model_name="gpt-4.1-nano"
)

# %%
question = "대한민국의 수도는 어디인가요?"
response=llm.invoke(question)
print(f"[답변] : {response}")
# Out:
# [답변] : content='대한민국의 수도는 서울입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 16, 'total_tokens': 24, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_8b64c33705', 'id': 'chatcmpl-EMr5NXjVCeNIj58bW3wZpVudVne2l', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a08f9f-6dd4-7542-80ba-63c441f8a957-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 8, 'total_tokens': 24, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(response.response_metadata)
# Out:
# {'token_usage': {'completion_tokens': 8, 'prompt_tokens': 16, 'total_tokens': 24, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_8b64c33705', 'id': 'chatcmpl-EMr5NXjVCeNIj58bW3wZpVudVne2l', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}

# %% [markdown]
# ## Invoke
# 함수 응답 출력

# %%
# from langchain_teddynote import logging
from langchain_teddynote.messages import stream_response  # 스트리밍 출력
from langchain_core.prompts import PromptTemplate

# %%
template = "{country}의 수도는 어디인가요?"

# from_template 메소드를 이용하여 PromptTemplate 객체 생성
prompt_template = PromptTemplate.from_template(template)
prompt_template
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?')

# %%
prompt = prompt_template.format(country="대한민국")
prompt
# Out:
# '대한민국의 수도는 어디인가요?'

# %%
prompt = prompt_template.format(country="미국")
prompt
# Out:
# '미국의 수도는 어디인가요?'

# %%
prompt = PromptTemplate.from_template("{topic} 에 대해 쉽게 설명해주세요.")

model = ChatOpenAI(model="gpt-4.1-nano", temperature=0.1)

chain = prompt | model

# %%
input = {"topic": "인공지능 모델의 학습 원리"}
chain.invoke(input)
# Out:
# AIMessage(content="물론입니다! 인공지능 모델의 학습 원리를 쉽게 설명해 드릴게요.\n\n1. **데이터 수집**: 먼저, 인공지능이 배우기 위해 많은 예제(데이터)를 모아요. 예를 들어, 고양이 사진을 많이 보여주는 거죠.\n\n2. **모델 설계**: 그런 다음, 이 데이터를 이해하고 학습할 수 있도록 인공지능의 구조(모델)를 만듭니다. 이 구조는 사람의 뇌와 비슷하게 여러 층으로 이루어진 '신경망'이라는 것일 수 있어요.\n\n3. **학습 과정**:\n   - 인공지능은 처음에는 아무것도 모르기 때문에, 사진이 고양이인지 아닌지 맞추기 어렵습니다.\n   - 그래서, 모델이 예측한 결과와 실제 정답(고양이 사진인지 아닌지)을 비교해서 차이(오차)를 계산해요.\n   - 이 오차를 줄이기 위해, 모델 내부의 '가중치'라는 값을 조금씩 조정합니다.\n   - 이 과정을 여러 번 반복하면서, 모델은 점점 더 정확하게 사진이 고양이인지 아닌지 구별할 수 있게 됩니다.\n\n4. **학습 완료**: 충분히 반복해서 학습하면, 모델은 새로운 사진이 주어졌을 때도 고양이인지 아닌지 잘 맞출 수 있게 돼요.\n\n요약하자면, 인공지능은 많은 예제 데이터를 보고, 정답과 비교하면서 점점 더 똑똑해지고, 이를 통해 새로운 문제도 해결할 수 있게 되는 거예요!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 346, 'prompt_tokens': 22, 'total_tokens': 368, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_fe1e84f9af', 'id': 'chatcmpl-EMr5OXhQlNSswdMK6cA6mZuJQjyf6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a08f9f-71a0-7461-a473-b9f2add81a97-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 346, 'total_tokens': 368, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
answer = chain.stream(input)
stream_response(answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 answer = chain.stream(input)
# ----> 2 stream_response(answer)
#
# NameError: name 'stream_response' is not defined

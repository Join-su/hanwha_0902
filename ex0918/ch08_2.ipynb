# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
FILE_PATH = "./data/SPRI_AI_Brief_2023년12월호_F.pdf"

# %%
def show_metadata(docs):
    if docs:
        print("[metadata]")
        print(list(docs[0].metadata.keys()))
        print("\n[examples]")
        max_key_length = max(len(k) for k in docs[0].metadata.keys())
        for k, v in docs[0].metadata.items():
            print(f"{k:<{max_key_length}} : {v}")

# %%
from langchain_community.document_loaders import PyPDFLoader

# 파일 경로 설정
loader = PyPDFLoader(FILE_PATH)

# PDF 로더 초기화
docs = loader.load()

# 문서의 내용 출력
print(docs[10].page_content[:300])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9884\3460742005.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# SPRi AI Brief |
# 2023-12월호
# 8
# 코히어, 데이터 투명성 확보를 위한 데이터 출처 탐색기 공개
# n 코히어와 12개 기관이  광범위한 데이터셋에 대한 감사를 통해 원본 데이터 출처, 재라이선스 상태,
# 작성자 등 다양한 정보를 제공하는 ‘데이터 출처 탐색기’ 플랫폼을 출시
# n 대화형 플랫폼을 통해 개발자는 데이터셋의 라이선스 상태를 쉽게 파악할 수 있으며 데이터셋의
# 구성과 계보도 추적 가능
# KEY Contents
# £ 데이터 출처 탐색기, 광범위한 데이터셋 정보 제공을 통해 데이터 투명성 향상
# n AI 기업 코히어

# %%
# 메타데이터 출력
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'author', 'moddate', 'pdfversion', 'source', 'total_pages', 'page', 'page_label']
#
# [examples]
# producer     : Hancom PDF 1.3.0.542
# creator      : Hwp 2018 10.0.0.13462
# creationdate : 2023-12-08T13:28:38+09:00
# author       : dj
# moddate      : 2023-12-08T13:28:38+09:00
# pdfversion   : 1.4
# source       : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# total_pages  : 23
# page         : 0
# page_label   : 1

# %%
# PDF 로더 초기화, 이미지 추출 옵션 활성화
loader = PyPDFLoader("https://arxiv.org/pdf/2103.15348.pdf", extract_images=True)

# PDF 페이지 로드
docs = loader.load()

# 페이지 내용 접근
print(docs[4].page_content[:300])
# Out:
# [INFO] 2026-09-18 17:35:47,347 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-09-18 17:35:47,643 [RapidOCR] download_file.py:60: File exists and is valid: D:\jis_project\RAG_env\.venv\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.onnx
# [INFO] 2026-09-18 17:35:47,643 [RapidOCR] main.py:63: Using D:\jis_project\RAG_env\.venv\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.onnx
# [INFO] 2026-09-18 17:35:47,711 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-09-18 17:35:47,742 [RapidOCR] download_file.py:60: File exists and is valid: D:\jis_project\RAG_env\.venv\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-09-18 17:35:47,744 [RapidOCR] main.py:63: Using D:\jis_project\RAG_env\.venv\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-09-18 17:35:47,807 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-09-18 17:35:47,866 [RapidOCR] download_file.py:60: File exists and is valid: D:\jis_project\RAG_env\.venv\Lib\site-packages\rapidocr\models\PP-OCRv6_rec_small.onnx
# [INFO] 2026-09-18 17:35:47,866 [RapidOCR] main.py:63: Using D:\jis_project\RAG_env\.venv\Lib\site-packages\rapidocr\models\PP-OCRv6_rec_small.onnx
# LayoutParser: A Uniﬁed Toolkit for DL-Based DIA 5
# Table 1: Current layout detection models in the LayoutParser model zoo
# Dataset Base Model 1 Large Model Notes
# PubLayNet [38] F / M M Layouts of modern scientiﬁc documents
# PRImA [3] M - Layouts of scanned modern magazines and scientiﬁc reports
# Newspap

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'author', 'keywords', 'moddate', 'ptex.fullbanner', 'subject', 'title', 'trapped', 'source', 'total_pages', 'page', 'page_label']
#
# [examples]
# producer        : pdfTeX-1.40.21
# creator         : LaTeX with hyperref
# creationdate    : 2021-06-22T01:27:10+00:00
# author          :
# keywords        :
# moddate         : 2021-06-22T01:27:10+00:00
# ptex.fullbanner : This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2
# subject         :
# title           :
# trapped         : /False
# source          : https://arxiv.org/pdf/2103.15348.pdf
# total_pages     : 16
# page            : 0
# page_label      : 1

# %%
from langchain_community.document_loaders import PyMuPDFLoader

# PyMuPDF 로더 인스턴스 생성
loader = PyMuPDFLoader(FILE_PATH)

# 문서 로드
docs = loader.load()

# 문서의 내용 출력
print(docs[10].page_content[:300])
# Out:
# SPRi AI Brief |
# 2023-12월호
# 8
# 코히어, 데이터 투명성 확보를 위한 데이터 출처 탐색기 공개
# n 코히어와 12개 기관이  광범위한 데이터셋에 대한 감사를 통해 원본 데이터 출처, 재라이선스 상태,
# 작성자 등 다양한 정보를 제공하는 ‘데이터 출처 탐색기’ 플랫폼을 출시
# n 대화형 플랫폼을 통해 개발자는 데이터셋의 라이선스 상태를 쉽게 파악할 수 있으며 데이터셋의
# 구성과 계보도 추적 가능
# KEY Contents
# £ 데이터 출처 탐색기, 광범위한 데이터셋 정보 제공을 통해 데이터 투명성 향상
# n AI 기업 코히어

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'source', 'file_path', 'total_pages', 'format', 'title', 'author', 'subject', 'keywords', 'moddate', 'trapped', 'modDate', 'creationDate', 'page']
#
# [examples]
# producer     : Hancom PDF 1.3.0.542
# creator      : Hwp 2018 10.0.0.13462
# creationdate : 2023-12-08T13:28:38+09:00
# source       : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# file_path    : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# total_pages  : 23
# format       : PDF 1.4
# title        :
# author       : dj
# subject      :
# keywords     :
# moddate      : 2023-12-08T13:28:38+09:00
# trapped      :
# modDate      : D:20231208132838+09'00'
# creationDate : D:20231208132838+09'00'
# page         : 0

# %%
# from langchain_community.document_loaders import UnstructuredPDFLoader

# # UnstructuredPDFLoader 인스턴스 생성
# loader = UnstructuredPDFLoader(FILE_PATH)

# # 데이터 로드
# docs = loader.load()

# # 문서의 내용 출력
# print(docs[0].page_content[:300])

# %%
from langchain_community.document_loaders import PyPDFium2Loader

# PyPDFium2 로더 인스턴스 생성
loader = PyPDFium2Loader(FILE_PATH)

# 데이터 로드
docs = loader.load()

# 문서의 내용 출력
print(docs[10].page_content[:300])
# Out:
# SPRi AI Brief |
# 2023-12월호
# 8
# 코히어, 데이터 투명성 확보를 위한 데이터 출처 탐색기 공개
# n 코히어와 12개 기관이 광범위한 데이터셋에 대한 감사를 통해 원본 데이터 출처, 재라이선스 상태, 작성자 등 다양한 정보를 제공하는 ‘데이터 출처 탐색기’ 플랫폼을 출시
# n 대화형 플랫폼을 통해 개발자는 데이터셋의 라이선스 상태를 쉽게 파악할 수 있으며 데이터셋의
# 구성과 계보도 추적 가능
# KEY Contents
# £ 데이터 출처 탐색기, 광범위한 데이터셋 정보 제공을 통해 데이터 투명성 향상
# n AI 기업 코히어(Co

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'title', 'author', 'subject', 'keywords', 'moddate', 'source', 'total_pages', 'page']
#
# [examples]
# producer     : Hancom PDF 1.3.0.542
# creator      : Hwp 2018 10.0.0.13462
# creationdate : 2023-12-08T13:28:38+09:00
# title        :
# author       : dj
# subject      :
# keywords     :
# moddate      : 2023-12-08T13:28:38+09:00
# source       : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# total_pages  : 23
# page         : 0

# %%
# from langchain_community.document_loaders import PDFMinerLoader

# # PDFMiner 로더 인스턴스 생성
# loader = PDFMinerLoader(FILE_PATH)

# # 데이터 로드
# docs = loader.load()

# # 문서의 내용 출력
# print(docs[0].page_content[:300])

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader

# 디렉토리 경로
loader = PyPDFDirectoryLoader("data/")

# 문서 로드
docs = loader.load()

# 문서의 개수 출력
print(len(docs))
# Out:
# 23

# %%
# 문서의 내용 출력
print(docs[0].page_content[:300])
# Out:
# 2023년 12월호

# %%
# metadata 출력
print(docs[0].metadata)
# Out:
# {'producer': 'Hancom PDF 1.3.0.542', 'creator': 'Hwp 2018 10.0.0.13462', 'creationdate': '2023-12-08T13:28:38+09:00', 'author': 'dj', 'moddate': '2023-12-08T13:28:38+09:00', 'pdfversion': '1.4', 'source': 'data\\SPRI_AI_Brief_2023년12월호_F.pdf', 'total_pages': 23, 'page': 0, 'page_label': '1'}

# %%
# from langchain_community.document_loaders import PDFPlumberLoader

# # PDF 문서 로더 인스턴스 생성
# loader = PDFPlumberLoader(FILE_PATH)

# # 문서 로딩
# # docs = loader.load()

# # 첫 번째 문서 데이터 접근
# print(docs[10].page_content[:300])
